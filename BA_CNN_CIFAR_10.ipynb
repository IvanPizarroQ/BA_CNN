# %% [markdown]
# <H3 align='center'> An Attention-Based Architecture for
# Hierarchical Classification with CNNs </H3>
#
# <H5 align='center'> CIFAR-10 </H3>
#
# <hr style="height:2px;border:none"/>

# %% [markdown]
# # Dependencies

# %%
import keras
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten, Concatenate, Add, Softmax
from keras.layers import Conv2D, MaxPooling2D, Input, BatchNormalization
from keras.initializers import he_normal
from keras import optimizers
from keras.callbacks import LearningRateScheduler, TensorBoard, CSVLogger
from keras.utils.data_utils import get_file
from keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers
from keras.utils.vis_utils import plot_model
import pickle
from keras.models import load_model
from keras.callbacks import CSVLogger
from tensorflow.keras.utils import set_random_seed
from scipy import stats

# Computes hierarchical metrics proposed by Kiritchenko et al (2005)
def hierarchical_metrics(true,pred):
  true_labels = []
  true_fine = true[2].argmax(axis=1)
  true_c2 = true[1].argmax(axis=1)
  true_c1 = true[0].argmax(axis=1)
  for i in range(len(true_fine)):
    true_labels.append([true_c1[i],true_c2[i],true_fine[i]])
  pred_labels = []
  pred_c1 = pred[0].argmax(axis = 1)
  pred_c2 = pred[1].argmax(axis = 1)
  pred_fine = pred[2].argmax(axis = 1) 
  for i in range(len(pred_c1)):
    pred_labels.append([pred_c1[i],pred_c2[i],pred_fine[i]])
  preci = precision(true_labels,pred_labels)
  reca = recall(true_labels,pred_labels)
  f_1 = f1(true_labels,pred_labels)
  return preci,reca,f_1

# Hierarchical metrics, proposed by Kiritchenko et al (2005)
# Implementation 
# https://gitlab.com/dacs-hpi/hiclass/-/blob/main/hiclass/metrics.py


def precision(y_true: np.ndarray, y_pred: np.ndarray):
    """
    Compute precision score for hierarchical classification.

    hP = sum(|S intersection T|) / sum(|S|),
    where S is the set consisting of the most specific class(es) predicted for a test example and all respective ancestors
    and T is the set consisting of the true most specific class(es) for a test example and all respective ancestors.

    Parameters
    ----------
    y_true : np.array of shape (n_samples, n_levels)
        Ground truth (correct) labels.
    y_pred : np.array of shape (n_samples, n_levels)
        Predicted labels, as returned by a classifier.
    Returns
    -------
    precision : float
        What proportion of positive identifications was actually correct?
    """
    assert len(y_true) == len(y_pred)
    sum_intersection = 0
    sum_prediction_and_ancestors = 0
    for ground_truth, prediction in zip(y_true, y_pred):
        sum_intersection = sum_intersection + len(
            set(ground_truth).intersection(set(prediction))
        )
        sum_prediction_and_ancestors = sum_prediction_and_ancestors + len(
            set(prediction)
        )
    precision = sum_intersection / sum_prediction_and_ancestors
    return precision


def recall(y_true: np.ndarray, y_pred: np.ndarray):
    """
    Compute recall score for hierarchical classification.

    hR = sum(|S intersection T|) / sum(|T|),
    where S is the set consisting of the most specific class(es) predicted for a test example and all respective ancestors
    and T is the set consisting of the true most specific class(es) for a test example and all respective ancestors.

    Parameters
    ----------
    y_true : np.array of shape (n_samples, n_levels)
        Ground truth (correct) labels.
    y_pred : np.array of shape (n_samples, n_levels)
        Predicted labels, as returned by a classifier.
    Returns
    -------
    recall : float
        What proportion of actual positives was identified correctly?
    """
    assert len(y_true) == len(y_pred)
    sum_intersection = 0
    sum_prediction_and_ancestors = 0
    for ground_truth, prediction in zip(y_true, y_pred):
        sum_intersection = sum_intersection + len(
            set(ground_truth).intersection(set(prediction))
        )
        sum_prediction_and_ancestors = sum_prediction_and_ancestors + len(
            set(ground_truth)
        )
    recall = sum_intersection / sum_prediction_and_ancestors
    return recall


def f1(y_true: np.ndarray, y_pred: np.ndarray):
    """
    Compute f1 score for hierarchical classification.

    hF = 2 * hP * hR / (hP + hR),
    where hP is the hierarchical precision and hR is the hierarchical recall.

    Parameters
    ----------
    y_true : np.array of shape (n_samples, n_levels)
        Ground truth (correct) labels.
    y_pred : np.array of shape (n_samples, n_levels)
        Predicted labels, as returned by a classifier.
    Returns
    -------
    f1 : float
        Weighted average of the precision and recall
    """
    assert len(y_true) == len(y_pred)
    prec = precision(y_true, y_pred)
    rec = recall(y_true, y_pred)
    f1 = 2 * prec * rec / (prec + rec)
    return f1

# %% [markdown]
# # General Settings

# %%
#-------- dimensions ---------
img_rows, img_cols = 32, 32
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_rows, img_cols)
else:
    input_shape = (img_rows, img_cols, 3)
#-----------------------------

train_size = 50000

#--- coarse 1 classes ---
num_c_1 = 2
#--- coarse 2 classes ---
num_c_2 = 7
#--- fine classes ---
num_classes  = 10

batch_size   = 128
epochs       = 60

# %%
#-------------------- data loading ----------------------
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
y_train = to_categorical(y_train, num_classes)
y_cm = y_test
y_test = to_categorical(y_test, num_classes)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

#---------------- data preprocessing -------------------
x_train = (x_train-np.mean(x_train)) / np.std(x_train)
x_test = (x_test-np.mean(x_test)) / np.std(x_test)

# %%
#---------------------- make coarse 2 labels --------------------------
parent_f = {
  2:3, 3:5, 5:5,
  1:2, 7:6, 4:6,
  0:0, 6:4, 8:1, 9:2
}

y_c2_train = np.zeros((y_train.shape[0], num_c_2)).astype("float32")
y_c2_test = np.zeros((y_test.shape[0], num_c_2)).astype("float32")
for i in range(y_c2_train.shape[0]):
  y_c2_train[i][parent_f[np.argmax(y_train[i])]] = 1.0
for i in range(y_c2_test.shape[0]):
  y_c2_test[i][parent_f[np.argmax(y_test[i])]] = 1.0

#---------------------- make coarse 1 labels --------------------------
parent_c2 = {
  0:0, 1:0, 2:0,
  3:1, 4:1, 5:1, 6:1
}
y_c1_train = np.zeros((y_c2_train.shape[0], num_c_1)).astype("float32")
y_c1_test = np.zeros((y_c2_test.shape[0], num_c_1)).astype("float32")
for i in range(y_c1_train.shape[0]):
  y_c1_train[i][parent_c2[np.argmax(y_c2_train[i])]] = 1.0
for i in range(y_c1_test.shape[0]):
  y_c1_test[i][parent_c2[np.argmax(y_c2_test[i])]] = 1.0

# %%
# Learning rate scheduler
def scheduler(epoch):
  learning_rate_init = 0.003
  if epoch > 42:
    learning_rate_init = 0.0005
  if epoch > 52:
    learning_rate_init = 0.0001
  return learning_rate_init

# %%
# Loss Weights modifier, when BT-strategy is used
class LossWeightsModifier(keras.callbacks.Callback):
  def __init__(self, alpha, beta, gamma):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
  def on_epoch_end(self, epoch, logs={}):
    if epoch == 10:
      K.set_value(self.alpha, 0.1)
      K.set_value(self.beta, 0.8)
      K.set_value(self.gamma, 0.1)
    if epoch == 20:
      K.set_value(self.alpha, 0.1)
      K.set_value(self.beta, 0.2)
      K.set_value(self.gamma, 0.7)
    if epoch == 30:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0)
      K.set_value(self.gamma, 1)

# %% [markdown]
# #Flat CNN Base B

# %%
#----------------------- model definition ---------------------------
img_input = Input(shape=input_shape, name='input')

#--- block 1 ---
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

#--- block 2 ---
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

#--- block 3 ---
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

#--- block 4 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

#--- fine block ---
x = Flatten(name='flatten')(x)
x = Dense(1024, activation='relu', name='fc_cifar10_1')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu', name='fc2')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
fine_pred = Dense(num_classes, activation='softmax', name='predictions_cifar10')(x)

model = Model(img_input, fine_pred, name='flat_cnn_base_b')

#----------------------- compile and fit ---------------------------
sgd = optimizers.SGD(learning_rate=0.003, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', 
              optimizer=sgd, 
              metrics=['accuracy'])

# %%
change_lr = LearningRateScheduler(scheduler)

# Training
history_base_b = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=0,
          callbacks=change_lr,
          validation_data=(x_test, y_test))

# Evaluation on test set
score_base_b = model.evaluate(x_test, y_test, verbose=0)
parameters_base_b = np.sum([K.count_params(w) for w in model.trainable_weights])

# Results
print("--- Flat CNN Base B ---")
print("Accuracy:",score_base_b[1])
print("Parameters:","{:,}".format(parameters_base_b))
# Out:
# --- Flat CNN Base B ---
# Accuracy: 0.8210999965667725
# Parameters: 7,851,338

# %% [markdown]
# # B-CNN Base B

# %%
# if True, the model uses BT-strategy for training
bt_strategy = True

# %%
#----------------------- model definition ---------------------------
if bt_strategy == True:
  alpha = K.variable(value=0.98, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.01, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.01, dtype="float32", name="gamma") # A3 in paper
else:
  alpha = K.variable(value=0.33, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.33, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.34, dtype="float32", name="gamma") # A3 in paper  

img_input = Input(shape=input_shape, name='input')

#--- block 1 ---
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

#--- block 2 ---
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

#--- coarse 1 branch ---
c_1_bch = Flatten(name='c1_flatten')(x)
c_1_bch = Dense(256, activation='relu', name='c1_fc_cifar10_1')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_bch = Dense(256, activation='relu', name='c1_fc2')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_pred = Dense(num_c_1, activation='softmax', name='c1_predictions_cifar10')(c_1_bch)

#--- block 3 ---
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

#--- coarse 2 branch ---
c_2_bch = Flatten(name='c2_flatten')(x)
c_2_bch = Dense(512, activation='relu', name='c2_fc_cifar10_1')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_bch = Dense(512, activation='relu', name='c2_fc2')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_pred = Dense(num_c_2, activation='softmax', name='c2_predictions_cifar10')(c_2_bch)

#--- block 4 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

#--- fine block ---
x = Flatten(name='flatten')(x)
x = Dense(1024, activation='relu', name='fc_cifar10_1')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu', name='fc2')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
fine_pred = Dense(num_classes, activation='softmax', name='predictions_cifar10')(x)

model = Model(img_input, [c_1_pred, c_2_pred, fine_pred], name='bcnn_base_b')

#----------------------- compile  ---------------------------
sgd = optimizers.SGD(learning_rate=0.003, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', 
              optimizer=sgd, 
              loss_weights=[alpha, beta, gamma],
              # optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "bcnn_base_b"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 32, 32, 3)]  0           []
#
#  block1_conv1 (Conv2D)          (None, 32, 32, 64)   1792        ['input[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 64)  256         ['block1_conv1[0][0]']
#  ormalization)
#
#  block1_conv2 (Conv2D)          (None, 32, 32, 64)   36928       ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 64)  256         ['block1_conv2[0][0]']
#  ormalization)
#
#  block1_pool (MaxPooling2D)     (None, 16, 16, 64)   0           ['batch_normalization_11[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 16, 16, 128)  73856       ['block1_pool[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 16, 16, 128)  512        ['block2_conv1[0][0]']
#  ormalization)
#
#  block2_conv2 (Conv2D)          (None, 16, 16, 128)  147584      ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 128)  512        ['block2_conv2[0][0]']
#  ormalization)
#
#  block2_pool (MaxPooling2D)     (None, 8, 8, 128)    0           ['batch_normalization_13[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 8, 8, 256)    295168      ['block2_pool[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 8, 8, 256)   1024        ['block3_conv1[0][0]']
#  ormalization)
#
#  block3_conv2 (Conv2D)          (None, 8, 8, 256)    590080      ['batch_normalization_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 8, 8, 256)   1024        ['block3_conv2[0][0]']
#  ormalization)
#
#  block3_pool (MaxPooling2D)     (None, 4, 4, 256)    0           ['batch_normalization_17[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 4, 4, 512)    1180160     ['block3_pool[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 4, 4, 512)   2048        ['block4_conv1[0][0]']
#  ormalization)
#
#  block4_conv2 (Conv2D)          (None, 4, 4, 512)    2359808     ['batch_normalization_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 4, 4, 512)   2048        ['block4_conv2[0][0]']
#  ormalization)
#
#  block4_pool (MaxPooling2D)     (None, 2, 2, 512)    0           ['batch_normalization_21[0][0]']
#
#  c1_flatten (Flatten)           (None, 8192)         0           ['block2_pool[0][0]']
#
#  c2_flatten (Flatten)           (None, 4096)         0           ['block3_pool[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['block4_pool[0][0]']
#
#  c1_fc_cifar10_1 (Dense)        (None, 256)          2097408     ['c1_flatten[0][0]']
#
#  c2_fc_cifar10_1 (Dense)        (None, 512)          2097664     ['c2_flatten[0][0]']
#
#  fc_cifar10_1 (Dense)           (None, 1024)         2098176     ['flatten[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 256)         1024        ['c1_fc_cifar10_1[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 512)         2048        ['c2_fc_cifar10_1[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 1024)        4096        ['fc_cifar10_1[0][0]']
#  ormalization)
#
#  dropout_2 (Dropout)            (None, 256)          0           ['batch_normalization_14[0][0]']
#
#  dropout_4 (Dropout)            (None, 512)          0           ['batch_normalization_18[0][0]']
#
#  dropout_6 (Dropout)            (None, 1024)         0           ['batch_normalization_22[0][0]']
#
#  c1_fc2 (Dense)                 (None, 256)          65792       ['dropout_2[0][0]']
#
#  c2_fc2 (Dense)                 (None, 512)          262656      ['dropout_4[0][0]']
#
#  fc2 (Dense)                    (None, 1024)         1049600     ['dropout_6[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 256)         1024        ['c1_fc2[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 512)         2048        ['c2_fc2[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 1024)        4096        ['fc2[0][0]']
#  ormalization)
#
#  dropout_3 (Dropout)            (None, 256)          0           ['batch_normalization_15[0][0]']
#
#  dropout_5 (Dropout)            (None, 512)          0           ['batch_normalization_19[0][0]']
#
#  dropout_7 (Dropout)            (None, 1024)         0           ['batch_normalization_23[0][0]']
#
#  c1_predictions_cifar10 (Dense)  (None, 2)           514         ['dropout_3[0][0]']
#
#  c2_predictions_cifar10 (Dense)  (None, 7)           3591        ['dropout_5[0][0]']
#
#  predictions_cifar10 (Dense)    (None, 10)           10250       ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 12,393,043
# Trainable params: 12,382,035
# Non-trainable params: 11,008
# __________________________________________________________________________________________________

# %%
# Callbacks 
change_lr = LearningRateScheduler(scheduler)
change_lw = LossWeightsModifier(alpha, beta, gamma)

if bt_strategy == True:
  cbks = [change_lr, change_lw]
else:
  cbks = [change_lr]

history_bcnn_b = model.fit(x_train, [y_c1_train, y_c2_train, y_train],
          batch_size=batch_size,
          epochs=epochs,
          verbose=0,
          callbacks=cbks,
          validation_data=(x_test, [y_c1_test, y_c2_test, y_test]))

score_b_cnn_b = model.evaluate(x_test, [y_c1_test, y_c2_test, y_test], verbose=0)
parameters_b_cnn_b = np.sum([K.count_params(w) for w in model.trainable_weights])

predictions = model.predict(x_test)
preci_b_cnn_b,reca_b_cnn_b,f1_b_cnn_b= hierarchical_metrics([y_c1_test, y_c2_test, y_test],predictions)

# Results
print("--- B-CNN Base B ---")
print("--- Accuracy per level ---")
print("Accuracy level 1:",score_b_cnn_b[4])
print("Accuracy level 2:",score_b_cnn_b[5])
print("Accuracy level 3:",score_b_cnn_b[6])
print("--- Hierarchical Metrics ---")
print("Precision:",preci_b_cnn_b)
print("Recall:",reca_b_cnn_b)
print("f1:",f1_b_cnn_b)
print("Parameters:","{:,}".format(parameters_b_cnn_b))
# Out:
# --- B-CNN Base B ---
# --- Accuracy per level ---
# Accuracy level 1: 0.9581000208854675
# Accuracy level 2: 0.8691999912261963
# Accuracy level 3: 0.8438000082969666
# --- Hierarchical Metrics ---
# Precision: 0.9080192165558019
# Recall: 0.9100370370370371
# f1: 0.9090270070292268
# Parameters: 12,382,035

# %% [markdown]
# # BA-CNN Base B

# %%
# if True, the model uses BT-strategy for training
bt_strategy = True

# neurons of all dense layers on each branch 
branch_neurons = 256

# %%
#----------------------- model definition ---------------------------
if bt_strategy == True:
  alpha = K.variable(value=0.98, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.01, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.01, dtype="float32", name="gamma") # A3 in paper
else:
  alpha = K.variable(value=0.33, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.33, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.34, dtype="float32", name="gamma") # A3 in paper  

img_input = Input(shape=input_shape, name='input')

#--- block 1 ---
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

#--- block 2 ---
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

#--- coarse 1 branch ---
c_1_bch = Flatten(name='c1_flatten')(x)
c_1_bch = Dense(branch_neurons, activation='relu', name='c1_fc_cifar10_1')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_bch = Dense(branch_neurons, activation='relu', name='c1_fc2')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch_out = Dropout(0.5)(c_1_bch)

#--- block 3 ---
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

#--- coarse 2 branch ---
c_2_bch = Flatten(name='c2_flatten')(x)
c_2_bch = Dense(branch_neurons, activation='relu', name='c2_fc_cifar10_1')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_bch = Dense(branch_neurons, activation='relu', name='c2_fc2')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch_out = Dropout(0.5)(c_2_bch)

#--- block 4 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

#--- fine block ---
x = Flatten(name='flatten')(x)
x = Dense(branch_neurons, activation='relu', name='fc_cifar10_1')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(branch_neurons, activation='relu', name='fc2')(x)
x = BatchNormalization()(x)
x_out = Dropout(0.5)(x)


#-- Att for coarse 1---
# Coarse 1
sfcn_1_1 = Dense(64, name='fc1_1')(c_1_bch_out)
sfcn_1_1 = Dense(1, name='fc1_2')(sfcn_1_1)
# Coarse 2
sfcn_1_2 = Dense(64, name='fc1_3')(c_2_bch_out)
sfcn_1_2 = Dense(1, name='fc1_4')(sfcn_1_2)
# Fine
sfcn_1_3 = Dense(64, name='fc1_5')(x_out)
sfcn_1_3 = Dense(1, name='fc1_6')(sfcn_1_3)

score_vector_1 = Concatenate()([sfcn_1_1,sfcn_1_2,sfcn_1_3]) # Score vector 1
att_weights_1 = Activation('softmax', name='attention_weights_1')(score_vector_1) # Attention weights 1
weightned_sum_1 = Add()([c_1_bch_out*att_weights_1[0][0],c_2_bch_out*att_weights_1[0][1],x_out*att_weights_1[0][2]]) # Weightned sum 1

# Concat and prediction
coarse_1_concat = Concatenate()([c_1_bch_out,weightned_sum_1])
c_1_pred = Dense(num_c_1, activation='softmax', name='c1_predictions_cifar10')(coarse_1_concat)


#-- Att for coarse 2---

# Coarse 1
sfcn_2_1 = Dense(64, name='fc2_1')(c_1_bch_out)
sfcn_2_1 = Dense(1, name='fc2_2')(sfcn_2_1)
# Coarse 2
sfcn_2_2 = Dense(64, name='fc2_3')(c_2_bch_out)
sfcn_2_2 = Dense(1, name='fc2_4')(sfcn_2_2)
# Fine
sfcn_2_3 = Dense(64, name='fc2_5')(x_out)
sfcn_2_3 = Dense(1, name='fc2_6')(sfcn_2_3)

score_vector_2 = Concatenate()([sfcn_2_1,sfcn_2_2,sfcn_2_3]) # Score vector 1
att_weights_2 = Activation('softmax', name='attention_weights_2')(score_vector_2) # Attention weights 1
weightned_sum_2 = Add()([c_1_bch_out*att_weights_2[0][0],c_2_bch_out*att_weights_2[0][1],x_out*att_weights_2[0][2]]) # Weightned sum 1

# Concat and prediction
coarse_2_concat = Concatenate()([c_2_bch_out,weightned_sum_2])
c_2_pred = Dense(num_c_2, activation='softmax', name='c2_predictions_cifar10')(coarse_2_concat)


#-- Att for fine---

# Coarse 1
sfcn_3_1 = Dense(64, name='fc3_1')(c_1_bch_out)
sfcn_3_1 = Dense(1, name='fc3_2')(sfcn_3_1)
# Coarse 2
sfcn_3_2 = Dense(64, name='fc3_3')(c_2_bch_out)
sfcn_3_2 = Dense(1, name='fc3_4')(sfcn_3_2)
# Fine
sfcn_3_3 = Dense(64, name='fc3_5')(x_out)
sfcn_3_3 = Dense(1, name='fc3_6')(sfcn_3_3)

score_vector_3 = Concatenate()([sfcn_3_1,sfcn_3_2,sfcn_3_3]) # Score vector 1
att_weights_3 = Activation('softmax', name='attention_weights_3')(score_vector_3) # Attention weights 1
weightned_sum_3 = Add()([c_1_bch_out*att_weights_3[0][0],c_2_bch_out*att_weights_3[0][1],x_out*att_weights_3[0][2]]) # Weightned sum 3

# Concat and prediction
fine_concat = Concatenate()([x_out,weightned_sum_3])
fine_pred = Dense(num_classes, activation='softmax', name='predictions_cifar10')(fine_concat)

model = Model(img_input, [c_1_pred, c_2_pred, fine_pred], name='bacnn_base_b')

#----------------------- compile and fit ---------------------------
sgd = optimizers.SGD(learning_rate=0.003, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', 
              optimizer=sgd, 
              loss_weights=[alpha, beta, gamma],
              # optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "bacnn_base_b"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 32, 32, 3)]  0           []
#
#  block1_conv1 (Conv2D)          (None, 32, 32, 64)   1792        ['input[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 64)  256         ['block1_conv1[0][0]']
#  ormalization)
#
#  block1_conv2 (Conv2D)          (None, 32, 32, 64)   36928       ['batch_normalization_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 64)  256         ['block1_conv2[0][0]']
#  ormalization)
#
#  block1_pool (MaxPooling2D)     (None, 16, 16, 64)   0           ['batch_normalization_25[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 16, 16, 128)  73856       ['block1_pool[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 128)  512        ['block2_conv1[0][0]']
#  ormalization)
#
#  block2_conv2 (Conv2D)          (None, 16, 16, 128)  147584      ['batch_normalization_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 128)  512        ['block2_conv2[0][0]']
#  ormalization)
#
#  block2_pool (MaxPooling2D)     (None, 8, 8, 128)    0           ['batch_normalization_27[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 8, 8, 256)    295168      ['block2_pool[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 8, 8, 256)   1024        ['block3_conv1[0][0]']
#  ormalization)
#
#  block3_conv2 (Conv2D)          (None, 8, 8, 256)    590080      ['batch_normalization_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 8, 8, 256)   1024        ['block3_conv2[0][0]']
#  ormalization)
#
#  block3_pool (MaxPooling2D)     (None, 4, 4, 256)    0           ['batch_normalization_31[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 4, 4, 512)    1180160     ['block3_pool[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 4, 4, 512)   2048        ['block4_conv1[0][0]']
#  ormalization)
#
#  block4_conv2 (Conv2D)          (None, 4, 4, 512)    2359808     ['batch_normalization_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 4, 4, 512)   2048        ['block4_conv2[0][0]']
#  ormalization)
#
#  block4_pool (MaxPooling2D)     (None, 2, 2, 512)    0           ['batch_normalization_35[0][0]']
#
#  c1_flatten (Flatten)           (None, 8192)         0           ['block2_pool[0][0]']
#
#  c2_flatten (Flatten)           (None, 4096)         0           ['block3_pool[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['block4_pool[0][0]']
#
#  c1_fc_cifar10_1 (Dense)        (None, 256)          2097408     ['c1_flatten[0][0]']
#
#  c2_fc_cifar10_1 (Dense)        (None, 256)          1048832     ['c2_flatten[0][0]']
#
#  fc_cifar10_1 (Dense)           (None, 256)          524544      ['flatten[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 256)         1024        ['c1_fc_cifar10_1[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 256)         1024        ['c2_fc_cifar10_1[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 256)         1024        ['fc_cifar10_1[0][0]']
#  ormalization)
#
#  dropout_8 (Dropout)            (None, 256)          0           ['batch_normalization_28[0][0]']
#
#  dropout_10 (Dropout)           (None, 256)          0           ['batch_normalization_32[0][0]']
#
#  dropout_12 (Dropout)           (None, 256)          0           ['batch_normalization_36[0][0]']
#
#  c1_fc2 (Dense)                 (None, 256)          65792       ['dropout_8[0][0]']
#
#  c2_fc2 (Dense)                 (None, 256)          65792       ['dropout_10[0][0]']
#
#  fc2 (Dense)                    (None, 256)          65792       ['dropout_12[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 256)         1024        ['c1_fc2[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 256)         1024        ['c2_fc2[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 256)         1024        ['fc2[0][0]']
#  ormalization)
#
#  dropout_9 (Dropout)            (None, 256)          0           ['batch_normalization_29[0][0]']
#
#  dropout_11 (Dropout)           (None, 256)          0           ['batch_normalization_33[0][0]']
#
#  dropout_13 (Dropout)           (None, 256)          0           ['batch_normalization_37[0][0]']
#
#  fc1_1 (Dense)                  (None, 64)           16448       ['dropout_9[0][0]']
#
#  fc1_3 (Dense)                  (None, 64)           16448       ['dropout_11[0][0]']
#
#  fc1_5 (Dense)                  (None, 64)           16448       ['dropout_13[0][0]']
#
#  fc2_1 (Dense)                  (None, 64)           16448       ['dropout_9[0][0]']
#
#  fc2_3 (Dense)                  (None, 64)           16448       ['dropout_11[0][0]']
#
#  fc2_5 (Dense)                  (None, 64)           16448       ['dropout_13[0][0]']
#
#  fc3_1 (Dense)                  (None, 64)           16448       ['dropout_9[0][0]']
#
#  fc3_3 (Dense)                  (None, 64)           16448       ['dropout_11[0][0]']
#
#  fc3_5 (Dense)                  (None, 64)           16448       ['dropout_13[0][0]']
#
#  fc1_2 (Dense)                  (None, 1)            65          ['fc1_1[0][0]']
#
#  fc1_4 (Dense)                  (None, 1)            65          ['fc1_3[0][0]']
#
#  fc1_6 (Dense)                  (None, 1)            65          ['fc1_5[0][0]']
#
#  fc2_2 (Dense)                  (None, 1)            65          ['fc2_1[0][0]']
#
#  fc2_4 (Dense)                  (None, 1)            65          ['fc2_3[0][0]']
#
#  fc2_6 (Dense)                  (None, 1)            65          ['fc2_5[0][0]']
#
#  fc3_2 (Dense)                  (None, 1)            65          ['fc3_1[0][0]']
#
#  fc3_4 (Dense)                  (None, 1)            65          ['fc3_3[0][0]']
#
#  fc3_6 (Dense)                  (None, 1)            65          ['fc3_5[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['fc1_2[0][0]',
#                                                                   'fc1_4[0][0]',
#                                                                   'fc1_6[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 3)            0           ['fc2_2[0][0]',
#                                                                   'fc2_4[0][0]',
#                                                                   'fc2_6[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 3)            0           ['fc3_2[0][0]',
#                                                                   'fc3_4[0][0]',
#                                                                   'fc3_6[0][0]']
#
#  attention_weights_1 (Activatio  (None, 3)           0           ['concatenate[0][0]']
#  n)
#
#  attention_weights_2 (Activatio  (None, 3)           0           ['concatenate_2[0][0]']
#  n)
#
#  attention_weights_3 (Activatio  (None, 3)           0           ['concatenate_4[0][0]']
#  n)
#
#  tf.__operators__.getitem (Slic  (3,)                0           ['attention_weights_1[0][0]']
#  ingOpLambda)
#
#  tf.__operators__.getitem_2 (Sl  (3,)                0           ['attention_weights_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_4 (Sl  (3,)                0           ['attention_weights_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_6 (Sl  (3,)                0           ['attention_weights_2[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_8 (Sl  (3,)                0           ['attention_weights_2[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_10 (S  (3,)                0           ['attention_weights_2[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_12 (S  (3,)                0           ['attention_weights_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_14 (S  (3,)                0           ['attention_weights_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_16 (S  (3,)                0           ['attention_weights_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_1 (Sl  ()                  0           ['tf.__operators__.getitem[0][0]'
#  icingOpLambda)                                                  ]
#
#  tf.__operators__.getitem_3 (Sl  ()                  0           ['tf.__operators__.getitem_2[0][0
#  icingOpLambda)                                                  ]']
#
#  tf.__operators__.getitem_5 (Sl  ()                  0           ['tf.__operators__.getitem_4[0][0
#  icingOpLambda)                                                  ]']
#
#  tf.__operators__.getitem_7 (Sl  ()                  0           ['tf.__operators__.getitem_6[0][0
#  icingOpLambda)                                                  ]']
#
#  tf.__operators__.getitem_9 (Sl  ()                  0           ['tf.__operators__.getitem_8[0][0
#  icingOpLambda)                                                  ]']
#
#  tf.__operators__.getitem_11 (S  ()                  0           ['tf.__operators__.getitem_10[0][
#  licingOpLambda)                                                 0]']
#
#  tf.__operators__.getitem_13 (S  ()                  0           ['tf.__operators__.getitem_12[0][
#  licingOpLambda)                                                 0]']
#
#  tf.__operators__.getitem_15 (S  ()                  0           ['tf.__operators__.getitem_14[0][
#  licingOpLambda)                                                 0]']
#
#  tf.__operators__.getitem_17 (S  ()                  0           ['tf.__operators__.getitem_16[0][
#  licingOpLambda)                                                 0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 256)          0           ['dropout_9[0][0]',
#                                                                   'tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 256)         0           ['dropout_11[0][0]',
#  )                                                                'tf.__operators__.getitem_3[0][0
#                                                                  ]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 256)         0           ['dropout_13[0][0]',
#  )                                                                'tf.__operators__.getitem_5[0][0
#                                                                  ]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 256)         0           ['dropout_9[0][0]',
#  )                                                                'tf.__operators__.getitem_7[0][0
#                                                                  ]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 256)         0           ['dropout_11[0][0]',
#  )                                                                'tf.__operators__.getitem_9[0][0
#                                                                  ]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 256)         0           ['dropout_13[0][0]',
#  )                                                                'tf.__operators__.getitem_11[0][
#                                                                  0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, 256)         0           ['dropout_9[0][0]',
#  )                                                                'tf.__operators__.getitem_13[0][
#                                                                  0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 256)         0           ['dropout_11[0][0]',
#  )                                                                'tf.__operators__.getitem_15[0][
#                                                                  0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 256)         0           ['dropout_13[0][0]',
#  )                                                                'tf.__operators__.getitem_17[0][
#                                                                  0]']
#
#  add (Add)                      (None, 256)          0           ['tf.math.multiply[0][0]',
#                                                                   'tf.math.multiply_1[0][0]',
#                                                                   'tf.math.multiply_2[0][0]']
#
#  add_1 (Add)                    (None, 256)          0           ['tf.math.multiply_3[0][0]',
#                                                                   'tf.math.multiply_4[0][0]',
#                                                                   'tf.math.multiply_5[0][0]']
#
#  add_2 (Add)                    (None, 256)          0           ['tf.math.multiply_6[0][0]',
#                                                                   'tf.math.multiply_7[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 512)          0           ['dropout_9[0][0]',
#                                                                   'add[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 512)          0           ['dropout_11[0][0]',
#                                                                   'add_1[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 512)          0           ['dropout_13[0][0]',
#                                                                   'add_2[0][0]']
#
#  c1_predictions_cifar10 (Dense)  (None, 2)           1026        ['concatenate_1[0][0]']
#
#  c2_predictions_cifar10 (Dense)  (None, 7)           3591        ['concatenate_3[0][0]']
#
#  predictions_cifar10 (Dense)    (None, 10)           5130        ['concatenate_5[0][0]']
#
# ==================================================================================================
# Total params: 8,725,724
# Trainable params: 8,718,812
# Non-trainable params: 6,912
# __________________________________________________________________________________________________

# %%
# Callbacks 
change_lr = LearningRateScheduler(scheduler)
change_lw = LossWeightsModifier(alpha, beta, gamma)

if bt_strategy == True:
  cbks = [change_lr, change_lw]
else:
  cbks = [change_lr]

history_bacnn_b = model.fit(x_train, [y_c1_train, y_c2_train, y_train],
          batch_size=batch_size,
          epochs=epochs,
          verbose=0,
          callbacks=cbks,
          validation_data=(x_test, [y_c1_test, y_c2_test, y_test]))

score_ba_cnn_b = model.evaluate(x_test, [y_c1_test, y_c2_test, y_test], verbose=0)
parameters_ba_cnn_b = np.sum([K.count_params(w) for w in model.trainable_weights])

predictions = model.predict(x_test)
preci_ba_cnn_b,reca_ba_cnn_b,f1_ba_cnn_b= hierarchical_metrics([y_c1_test, y_c2_test, y_test],predictions)

# Results
print("--- BA-CNN Base B ---")
print("--- Accuracy per level ---")
print("Accuracy level 1:",score_ba_cnn_b[4])
print("Accuracy level 2:",score_ba_cnn_b[5])
print("Accuracy level 3:",score_ba_cnn_b[6])
print("--- Hierarchical Metrics ---")
print("Precision:",preci_ba_cnn_b)
print("Recall:",reca_ba_cnn_b)
print("f1:",f1_ba_cnn_b)
print("Parameters:","{:,}".format(parameters_ba_cnn_b))
# Out:
# --- BA-CNN Base B ---
# --- Accuracy per level ---
# Accuracy level 1: 0.9678999781608582
# Accuracy level 2: 0.8777999877929688
# Accuracy level 3: 0.8420000076293945
# --- Hierarchical Metrics ---
# Precision: 0.9141343018084791
# Recall: 0.9135925925925926
# f1: 0.913863366923533
# Parameters: 8,718,812

# %% [markdown]
# # H-CNN Base B

# %%
# if True, the model uses BT-strategy for training
bt_strategy = True

# %%
#----------------------- model definition ---------------------------
if bt_strategy == True:
  alpha = K.variable(value=0.98, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.01, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.01, dtype="float32", name="gamma") # A3 in paper
else:
  alpha = K.variable(value=0.33, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.33, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.34, dtype="float32", name="gamma") # A3 in paper  

img_input = Input(shape=input_shape, name='input')

#--- block 1 ---
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

#--- block 2 ---
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

#--- coarse 1 branch ---
c_1_bch_flatt = Flatten(name='c1_flatten')(x)
c_1_bch = Dense(256, activation='relu', name='c1_fc_cifar10_1')(c_1_bch_flatt)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_bch = Dense(256, activation='relu', name='c1_fc2')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_pred = Dense(num_c_1, activation='softmax', name='c1_predictions_cifar10')(c_1_bch)

#--- block 3 ---
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

#--- coarse 2 branch ---
c_2_bch_flatt = Flatten(name='c2_flatten')(x)
c_2_bch_concat = Concatenate()([c_1_bch_flatt,c_2_bch_flatt]) # Conectivity Pattern
c_2_bch = Dense(512, activation='relu', name='c2_fc_cifar100_1')(c_2_bch_concat)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_bch = Dense(512, activation='relu', name='c2_fc2')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_pred = Dense(num_c_2, activation='softmax', name='c2_predictions_cifar10')(c_2_bch)

#--- block 4 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

#--- fine block ---
x_flatt = Flatten(name='flatten')(x)
x = Concatenate()([c_2_bch_concat,x_flatt]) # Conectivity Pattern
x = Dense(1024, activation='relu', name='fc_cifar10_1')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu', name='fc2')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
fine_pred = Dense(num_classes, activation='softmax', name='predictions_cifar10')(x)

model = Model(img_input, [c_1_pred, c_2_pred, fine_pred], name='hcnn_base_b')

#----------------------- compile and fit ---------------------------
sgd = optimizers.SGD(learning_rate=0.003, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', 
              optimizer=sgd, 
              loss_weights=[alpha, beta, gamma],
              # optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "hcnn_base_b"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 32, 32, 3)]  0           []
#
#  block1_conv1 (Conv2D)          (None, 32, 32, 64)   1792        ['input[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 32, 32, 64)  256         ['block1_conv1[0][0]']
#  ormalization)
#
#  block1_conv2 (Conv2D)          (None, 32, 32, 64)   36928       ['batch_normalization_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 32, 32, 64)  256         ['block1_conv2[0][0]']
#  ormalization)
#
#  block1_pool (MaxPooling2D)     (None, 16, 16, 64)   0           ['batch_normalization_39[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 16, 16, 128)  73856       ['block1_pool[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 16, 16, 128)  512        ['block2_conv1[0][0]']
#  ormalization)
#
#  block2_conv2 (Conv2D)          (None, 16, 16, 128)  147584      ['batch_normalization_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 16, 16, 128)  512        ['block2_conv2[0][0]']
#  ormalization)
#
#  block2_pool (MaxPooling2D)     (None, 8, 8, 128)    0           ['batch_normalization_41[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 8, 8, 256)    295168      ['block2_pool[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 256)   1024        ['block3_conv1[0][0]']
#  ormalization)
#
#  block3_conv2 (Conv2D)          (None, 8, 8, 256)    590080      ['batch_normalization_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 256)   1024        ['block3_conv2[0][0]']
#  ormalization)
#
#  block3_pool (MaxPooling2D)     (None, 4, 4, 256)    0           ['batch_normalization_45[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 4, 4, 512)    1180160     ['block3_pool[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 4, 4, 512)   2048        ['block4_conv1[0][0]']
#  ormalization)
#
#  block4_conv2 (Conv2D)          (None, 4, 4, 512)    2359808     ['batch_normalization_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 4, 4, 512)   2048        ['block4_conv2[0][0]']
#  ormalization)
#
#  c1_flatten (Flatten)           (None, 8192)         0           ['block2_pool[0][0]']
#
#  c2_flatten (Flatten)           (None, 4096)         0           ['block3_pool[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 2, 2, 512)    0           ['batch_normalization_49[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 12288)        0           ['c1_flatten[0][0]',
#                                                                   'c2_flatten[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['block4_pool[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 14336)        0           ['concatenate_6[0][0]',
#                                                                   'flatten[0][0]']
#
#  c1_fc_cifar10_1 (Dense)        (None, 256)          2097408     ['c1_flatten[0][0]']
#
#  c2_fc_cifar100_1 (Dense)       (None, 512)          6291968     ['concatenate_6[0][0]']
#
#  fc_cifar10_1 (Dense)           (None, 1024)         14681088    ['concatenate_7[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 256)         1024        ['c1_fc_cifar10_1[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 512)         2048        ['c2_fc_cifar100_1[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 1024)        4096        ['fc_cifar10_1[0][0]']
#  ormalization)
#
#  dropout_14 (Dropout)           (None, 256)          0           ['batch_normalization_42[0][0]']
#
#  dropout_16 (Dropout)           (None, 512)          0           ['batch_normalization_46[0][0]']
#
#  dropout_18 (Dropout)           (None, 1024)         0           ['batch_normalization_50[0][0]']
#
#  c1_fc2 (Dense)                 (None, 256)          65792       ['dropout_14[0][0]']
#
#  c2_fc2 (Dense)                 (None, 512)          262656      ['dropout_16[0][0]']
#
#  fc2 (Dense)                    (None, 1024)         1049600     ['dropout_18[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 256)         1024        ['c1_fc2[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 512)         2048        ['c2_fc2[0][0]']
#  ormalization)
#
#  batch_normalization_51 (BatchN  (None, 1024)        4096        ['fc2[0][0]']
#  ormalization)
#
#  dropout_15 (Dropout)           (None, 256)          0           ['batch_normalization_43[0][0]']
#
#  dropout_17 (Dropout)           (None, 512)          0           ['batch_normalization_47[0][0]']
#
#  dropout_19 (Dropout)           (None, 1024)         0           ['batch_normalization_51[0][0]']
#
#  c1_predictions_cifar10 (Dense)  (None, 2)           514         ['dropout_15[0][0]']
#
#  c2_predictions_cifar10 (Dense)  (None, 7)           3591        ['dropout_17[0][0]']
#
#  predictions_cifar10 (Dense)    (None, 10)           10250       ['dropout_19[0][0]']
#
# ==================================================================================================
# Total params: 29,170,259
# Trainable params: 29,159,251
# Non-trainable params: 11,008
# __________________________________________________________________________________________________

# %%
# Callbacks 
change_lr = LearningRateScheduler(scheduler)
change_lw = LossWeightsModifier(alpha, beta, gamma)

if bt_strategy == True:
  cbks = [change_lr, change_lw]
else:
  cbks = [change_lr]

history_hcnn_b = model.fit(x_train, [y_c1_train, y_c2_train, y_train],
          batch_size=batch_size,
          epochs=epochs,
          verbose=0,
          callbacks=cbks,
          validation_data=(x_test, [y_c1_test, y_c2_test, y_test]))

score_h_cnn_b = model.evaluate(x_test, [y_c1_test, y_c2_test, y_test], verbose=0)
parameters_h_cnn_b = np.sum([K.count_params(w) for w in model.trainable_weights])

predictions = model.predict(x_test)
preci_h_cnn_b,reca_h_cnn_b,f1_h_cnn_b= hierarchical_metrics([y_c1_test, y_c2_test, y_test],predictions)

# Results
print("--- H-CNN Base B ---")
print("--- Accuracy per level ---")
print("Accuracy level 1:",score_h_cnn_b[4])
print("Accuracy level 2:",score_h_cnn_b[5])
print("Accuracy level 3:",score_h_cnn_b[6])
print("--- Hierarchical Metrics ---")
print("Precision:",preci_h_cnn_b)
print("Recall:",reca_h_cnn_b)
print("f1:",f1_h_cnn_b)
print("Parameters:","{:,}".format(parameters_h_cnn_b))
# Out:
# --- H-CNN Base B ---
# --- Accuracy per level ---
# Accuracy level 1: 0.9585999846458435
# Accuracy level 2: 0.8716999888420105
# Accuracy level 3: 0.836899995803833
# --- Hierarchical Metrics ---
# Precision: 0.906301854788156
# Recall: 0.9102962962962963
# f1: 0.9082946839372494
# Parameters: 29,159,251

# %% [markdown]
# # Flat CNN Base C

# %%
#----------get VGG16 pre-trained weights--------
WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5'
weights_path = get_file('vgg16_weights_tf_dim_ordering_tf_kernels.h5',
                         WEIGHTS_PATH,
                         cache_subdir='models')
#----------------------- model definition ---------------------------
img_input = Input(shape=input_shape, name='input')

#--- block 1 ---
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

#--- block 2 ---
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

#--- block 3 ---
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

#--- block 4 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

#--- block 5 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
x = BatchNormalization()(x)

#--- fine block ---
x = Flatten(name='flatten')(x)
x = Dense(4096, activation='relu', name='fc_cifar100_1')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(4096, activation='relu', name='fc_cifar100_2')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
fine_pred = Dense(num_classes, activation='softmax', name='predictions_cifar10')(x)

model = Model(img_input, fine_pred, name='flat_cnn_base_c')
model.load_weights(weights_path, by_name=True)

#----------------------- compile and fit ---------------------------
sgd = optimizers.SGD(learning_rate=0.001, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', 
              optimizer=sgd, 
              # optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 87s 0us/step
# 553476096/553467096 [==============================] - 87s 0us/step
# Model: "flat_cnn_base_c"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  batch_normalization_52 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  batch_normalization_53 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  batch_normalization_54 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  batch_normalization_55 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  batch_normalization_56 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  batch_normalization_57 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  batch_normalization_58 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  batch_normalization_59 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_60 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_61 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  batch_normalization_62 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  batch_normalization_63 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  batch_normalization_64 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  fc_cifar100_1 (Dense)       (None, 4096)              8392704
#
#  batch_normalization_65 (Bat  (None, 4096)             16384
#  chNormalization)
#
#  dropout_20 (Dropout)        (None, 4096)              0
#
#  fc_cifar100_2 (Dense)       (None, 4096)              16781312
#
#  batch_normalization_66 (Bat  (None, 4096)             16384
#  chNormalization)
#
#  dropout_21 (Dropout)        (None, 4096)              0
#
#  predictions_cifar10 (Dense)  (None, 10)               40970
#
# =================================================================
# Total params: 39,979,338
# Trainable params: 39,954,506
# Non-trainable params: 24,832
# _________________________________________________________________

# %%
change_lr = LearningRateScheduler(scheduler)

# Training
history_base_c = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=0,
          callbacks=change_lr,
          validation_data=(x_test, y_test))

# Evaluation on test set
score_base_c = model.evaluate(x_test, y_test, verbose=0)
parameters_base_c = np.sum([K.count_params(w) for w in model.trainable_weights])

# %% [markdown]
# # B-CNN Base C

# %%
# if True, the model uses BT-strategy for training
bt_strategy = True

# %%
#----------get VGG16 pre-trained weights--------
WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5'
weights_path = get_file('vgg16_weights_tf_dim_ordering_tf_kernels.h5',
                         WEIGHTS_PATH,
                         cache_subdir='models')

#----------------------- model definition ---------------------------
if bt_strategy == True:
  alpha = K.variable(value=0.98, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.01, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.01, dtype="float32", name="gamma") # A3 in paper
else:
  alpha = K.variable(value=0.33, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.33, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.34, dtype="float32", name="gamma") # A3 in paper  


img_input = Input(shape=input_shape, name='input')

#--- block 1 ---
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

#--- block 2 ---
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

#--- coarse 1 branch ---
c_1_bch = Flatten(name='c1_flatten')(x)
c_1_bch = Dense(512, activation='relu', name='c1_fc_cifar10_1')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_bch = Dense(512, activation='relu', name='c1_fc2')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_pred = Dense(num_c_1, activation='softmax', name='c1_predictions_cifar10')(c_1_bch)

#--- block 3 ---
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

#--- coarse 2 branch ---
c_2_bch = Flatten(name='c2_flatten')(x)
c_2_bch = Dense(1024, activation='relu', name='c2_fc_cifar10_1')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_bch = Dense(1024, activation='relu', name='c2_fc2')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_pred = Dense(num_c_2, activation='softmax', name='c2_predictions_cifar10')(c_2_bch)

#--- block 4 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

#--- block 5 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
x = BatchNormalization()(x)

#--- fine block ---
x = Flatten(name='flatten')(x)
x = Dense(4096, activation='relu', name='fc_cifar10_1')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(4096, activation='relu', name='fc2')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
fine_pred = Dense(num_classes, activation='softmax', name='predictions_cifar10')(x)

model = Model(img_input, [c_1_pred, c_2_pred, fine_pred], name='bcnn_base_c')
model.load_weights(weights_path, by_name=True)
#----------------------- compile and fit ---------------------------
sgd = optimizers.SGD(learning_rate=0.003, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', 
              optimizer=sgd, 
              loss_weights=[alpha, beta, gamma],
              # optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "bcnn_base_c"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 32, 32, 3)]  0           []
#
#  block1_conv1 (Conv2D)          (None, 32, 32, 64)   1792        ['input[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 32, 32, 64)  256         ['block1_conv1[0][0]']
#  ormalization)
#
#  block1_conv2 (Conv2D)          (None, 32, 32, 64)   36928       ['batch_normalization_67[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 32, 32, 64)  256         ['block1_conv2[0][0]']
#  ormalization)
#
#  block1_pool (MaxPooling2D)     (None, 16, 16, 64)   0           ['batch_normalization_68[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 16, 16, 128)  73856       ['block1_pool[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 16, 16, 128)  512        ['block2_conv1[0][0]']
#  ormalization)
#
#  block2_conv2 (Conv2D)          (None, 16, 16, 128)  147584      ['batch_normalization_69[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 16, 16, 128)  512        ['block2_conv2[0][0]']
#  ormalization)
#
#  block2_pool (MaxPooling2D)     (None, 8, 8, 128)    0           ['batch_normalization_70[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 8, 8, 256)    295168      ['block2_pool[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 8, 8, 256)   1024        ['block3_conv1[0][0]']
#  ormalization)
#
#  block3_conv2 (Conv2D)          (None, 8, 8, 256)    590080      ['batch_normalization_73[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 8, 8, 256)   1024        ['block3_conv2[0][0]']
#  ormalization)
#
#  block3_conv3 (Conv2D)          (None, 8, 8, 256)    590080      ['batch_normalization_74[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 8, 8, 256)   1024        ['block3_conv3[0][0]']
#  ormalization)
#
#  block3_pool (MaxPooling2D)     (None, 4, 4, 256)    0           ['batch_normalization_75[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 4, 4, 512)    1180160     ['block3_pool[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 4, 4, 512)   2048        ['block4_conv1[0][0]']
#  ormalization)
#
#  block4_conv2 (Conv2D)          (None, 4, 4, 512)    2359808     ['batch_normalization_78[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 4, 4, 512)   2048        ['block4_conv2[0][0]']
#  ormalization)
#
#  block4_conv3 (Conv2D)          (None, 4, 4, 512)    2359808     ['batch_normalization_79[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 4, 4, 512)   2048        ['block4_conv3[0][0]']
#  ormalization)
#
#  block4_pool (MaxPooling2D)     (None, 2, 2, 512)    0           ['batch_normalization_80[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 2, 2, 512)    2359808     ['block4_pool[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 2, 2, 512)   2048        ['block5_conv1[0][0]']
#  ormalization)
#
#  block5_conv2 (Conv2D)          (None, 2, 2, 512)    2359808     ['batch_normalization_81[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 2, 2, 512)   2048        ['block5_conv2[0][0]']
#  ormalization)
#
#  block5_conv3 (Conv2D)          (None, 2, 2, 512)    2359808     ['batch_normalization_82[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 2, 2, 512)   2048        ['block5_conv3[0][0]']
#  ormalization)
#
#  c1_flatten (Flatten)           (None, 8192)         0           ['block2_pool[0][0]']
#
#  c2_flatten (Flatten)           (None, 4096)         0           ['block3_pool[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['batch_normalization_83[0][0]']
#
#  c1_fc_cifar10_1 (Dense)        (None, 512)          4194816     ['c1_flatten[0][0]']
#
#  c2_fc_cifar10_1 (Dense)        (None, 1024)         4195328     ['c2_flatten[0][0]']
#
#  fc_cifar10_1 (Dense)           (None, 4096)         8392704     ['flatten[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 512)         2048        ['c1_fc_cifar10_1[0][0]']
#  ormalization)
#
#  batch_normalization_76 (BatchN  (None, 1024)        4096        ['c2_fc_cifar10_1[0][0]']
#  ormalization)
#
#  batch_normalization_84 (BatchN  (None, 4096)        16384       ['fc_cifar10_1[0][0]']
#  ormalization)
#
#  dropout_22 (Dropout)           (None, 512)          0           ['batch_normalization_71[0][0]']
#
#  dropout_24 (Dropout)           (None, 1024)         0           ['batch_normalization_76[0][0]']
#
#  dropout_26 (Dropout)           (None, 4096)         0           ['batch_normalization_84[0][0]']
#
#  c1_fc2 (Dense)                 (None, 512)          262656      ['dropout_22[0][0]']
#
#  c2_fc2 (Dense)                 (None, 1024)         1049600     ['dropout_24[0][0]']
#
#  fc2 (Dense)                    (None, 4096)         16781312    ['dropout_26[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 512)         2048        ['c1_fc2[0][0]']
#  ormalization)
#
#  batch_normalization_77 (BatchN  (None, 1024)        4096        ['c2_fc2[0][0]']
#  ormalization)
#
#  batch_normalization_85 (BatchN  (None, 4096)        16384       ['fc2[0][0]']
#  ormalization)
#
#  dropout_23 (Dropout)           (None, 512)          0           ['batch_normalization_72[0][0]']
#
#  dropout_25 (Dropout)           (None, 1024)         0           ['batch_normalization_77[0][0]']
#
#  dropout_27 (Dropout)           (None, 4096)         0           ['batch_normalization_85[0][0]']
#
#  c1_predictions_cifar10 (Dense)  (None, 2)           1026        ['dropout_23[0][0]']
#
#  c2_predictions_cifar10 (Dense)  (None, 7)           7175        ['dropout_25[0][0]']
#
#  predictions_cifar10 (Dense)    (None, 10)           40970       ['dropout_27[0][0]']
#
# ==================================================================================================
# Total params: 49,702,227
# Trainable params: 49,671,251
# Non-trainable params: 30,976
# __________________________________________________________________________________________________

# %%
# Callbacks 
change_lr = LearningRateScheduler(scheduler)
change_lw = LossWeightsModifier(alpha, beta, gamma)

if bt_strategy == True:
  cbks = [change_lr, change_lw]
else:
  cbks = [change_lr]

history_bcnn_b = model.fit(x_train, [y_c1_train, y_c2_train, y_train],
          batch_size=batch_size,
          epochs=epochs,
          verbose=0,
          callbacks=cbks,
          validation_data=(x_test, [y_c1_test, y_c2_test, y_test]))

score_b_cnn_c = model.evaluate(x_test, [y_c1_test, y_c2_test, y_test], verbose=0)
parameters_b_cnn_c = np.sum([K.count_params(w) for w in model.trainable_weights])

predictions = model.predict(x_test)
preci_b_cnn_c,reca_b_cnn_c,f1_b_cnn_c= hierarchical_metrics([y_c1_test, y_c2_test, y_test],predictions)

# Results
print("--- B-CNN Base C ---")
print("--- Accuracy per level ---")
print("Accuracy level 1:",score_b_cnn_c[4])
print("Accuracy level 2:",score_b_cnn_c[5])
print("Accuracy level 3:",score_b_cnn_c[6])
print("--- Hierarchical Metrics ---")
print("Precision:",preci_b_cnn_c)
print("Recall:",reca_b_cnn_c)
print("f1:",f1_b_cnn_c)
print("Parameters:","{:,}".format(parameters_b_cnn_c))
# Out:
# --- B-CNN Base C ---
# --- Accuracy per level ---
# Accuracy level 1: 0.9603000283241272
# Accuracy level 2: 0.9053000211715698
# Accuracy level 3: 0.8884999752044678
# --- Hierarchical Metrics ---
# Precision: 0.9315478389360916
# Recall: 0.933962962962963
# f1: 0.9327538376179028
# Parameters: 49,671,251

# %% [markdown]
# # BA-CNN Base C

# %%
# if True, the model uses BT-strategy for training
bt_strategy = True

# neurons of all dense layers on each branch 
branch_neurons = 256

# %%
#----------get VGG16 pre-trained weights--------
WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5'
weights_path = get_file('vgg16_weights_tf_dim_ordering_tf_kernels.h5',
                         WEIGHTS_PATH,
                         cache_subdir='models')

#----------------------- model definition ---------------------------
if bt_strategy == True:
  alpha = K.variable(value=0.98, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.01, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.01, dtype="float32", name="gamma") # A3 in paper
else:
  alpha = K.variable(value=0.33, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.33, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.34, dtype="float32", name="gamma") # A3 in paper  


img_input = Input(shape=input_shape, name='input')

#--- block 1 ---
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

#--- block 2 ---
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

#--- coarse 1 branch ---
c_1_bch = Flatten(name='c1_flatten')(x)
c_1_bch = Dense(branch_neurons, activation='relu', name='c1_fc_cifar10_1')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_bch = Dense(branch_neurons, activation='relu', name='c1_fc2')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch_out = Dropout(0.5)(c_1_bch)
#c_1_pred = Dense(num_c_1, activation='softmax', name='c1_predictions_cifar10')(c_1_bch_out)

#--- block 3 ---
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

#--- coarse 2 branch ---
c_2_bch = Flatten(name='c2_flatten')(x)
c_2_bch = Dense(branch_neurons, activation='relu', name='c2_fc_cifar10_1')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_bch = Dense(branch_neurons, activation='relu', name='c2_fc2')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch_out = Dropout(0.5)(c_2_bch)
#c_2_pred = Dense(num_c_2, activation='softmax', name='c2_predictions_cifar10')(c_2_bch_out)

#--- block 4 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

#--- block 5 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
x = BatchNormalization()(x)

#--- fine block ---
x = Flatten(name='flatten')(x)
x = Dense(branch_neurons, activation='relu', name='fc_cifar10_1')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(branch_neurons, activation='relu', name='fc_cifar10_2')(x)
x = BatchNormalization()(x)
x_out = Dropout(0.5)(x)

#-- Att for coarse 1---
# Coarse 1
sfcn_1_1 = Dense(64, name='fc1_1')(c_1_bch_out)
sfcn_1_1 = Dense(1, name='fc1_2')(sfcn_1_1)
# Coarse 2
sfcn_1_2 = Dense(64, name='fc1_3')(c_2_bch_out)
sfcn_1_2 = Dense(1, name='fc1_4')(sfcn_1_2)
# Fine
sfcn_1_3 = Dense(64, name='fc1_5')(x_out)
sfcn_1_3 = Dense(1, name='fc1_6')(sfcn_1_3)

score_vector_1 = Concatenate()([sfcn_1_1,sfcn_1_2,sfcn_1_3]) # Score vector 1
att_weights_1 = Activation('softmax', name='attention_weights_1')(score_vector_1) # Attention weights 1
weightned_sum_1 = Add()([c_1_bch_out*att_weights_1[0][0],c_2_bch_out*att_weights_1[0][1],x_out*att_weights_1[0][2]]) # Weightned sum 1

# Concat and prediction
coarse_1_concat = Concatenate()([c_1_bch_out,weightned_sum_1])
c_1_pred = Dense(num_c_1, activation='softmax', name='c1_predictions_cifar10')(coarse_1_concat)


#-- Att for coarse 2---

# Coarse 1
sfcn_2_1 = Dense(64, name='fc2_1')(c_1_bch_out)
sfcn_2_1 = Dense(1, name='fc2_2')(sfcn_2_1)
# Coarse 2
sfcn_2_2 = Dense(64, name='fc2_3')(c_2_bch_out)
sfcn_2_2 = Dense(1, name='fc2_4')(sfcn_2_2)
# Fine
sfcn_2_3 = Dense(64, name='fc2_5')(x_out)
sfcn_2_3 = Dense(1, name='fc2_6')(sfcn_2_3)

score_vector_2 = Concatenate()([sfcn_2_1,sfcn_2_2,sfcn_2_3]) # Score vector 1
att_weights_2 = Activation('softmax', name='attention_weights_2')(score_vector_2) # Attention weights 1
weightned_sum_2 = Add()([c_1_bch_out*att_weights_2[0][0],c_2_bch_out*att_weights_2[0][1],x_out*att_weights_2[0][2]]) # Weightned sum 1

# Concat and prediction
coarse_2_concat = Concatenate()([c_2_bch_out,weightned_sum_2])
c_2_pred = Dense(num_c_2, activation='softmax', name='c2_predictions_cifar10')(coarse_2_concat)


#-- Att for fine---

# Coarse 1
sfcn_3_1 = Dense(64, name='fc3_1')(c_1_bch_out)
sfcn_3_1 = Dense(1, name='fc3_2')(sfcn_3_1)
# Coarse 2
sfcn_3_2 = Dense(64, name='fc3_3')(c_2_bch_out)
sfcn_3_2 = Dense(1, name='fc3_4')(sfcn_3_2)
# Fine
sfcn_3_3 = Dense(64, name='fc3_5')(x_out)
sfcn_3_3 = Dense(1, name='fc3_6')(sfcn_3_3)

score_vector_3 = Concatenate()([sfcn_3_1,sfcn_3_2,sfcn_3_3]) # Score vector 1
att_weights_3 = Activation('softmax', name='attention_weights_3')(score_vector_3) # Attention weights 1
weightned_sum_3 = Add()([c_1_bch_out*att_weights_3[0][0],c_2_bch_out*att_weights_3[0][1],x_out*att_weights_3[0][2]]) # Weightned sum 3

# Concat and prediction
fine_concat = Concatenate()([x_out,weightned_sum_3])
fine_pred = Dense(num_classes, activation='softmax', name='predictions_cifar10')(fine_concat)




model = Model(img_input, [c_1_pred, c_2_pred, fine_pred], name='bacnn_base_c')
model.load_weights(weights_path, by_name=True)
#----------------------- compile and fit ---------------------------
sgd = optimizers.SGD(learning_rate=0.003, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', 
              optimizer=sgd, 
              loss_weights=[alpha, beta, gamma],
              # optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "bacnn_base_c"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 32, 32, 3)]  0           []
#
#  block1_conv1 (Conv2D)          (None, 32, 32, 64)   1792        ['input[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 32, 32, 64)  256         ['block1_conv1[0][0]']
#  ormalization)
#
#  block1_conv2 (Conv2D)          (None, 32, 32, 64)   36928       ['batch_normalization_86[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 32, 32, 64)  256         ['block1_conv2[0][0]']
#  ormalization)
#
#  block1_pool (MaxPooling2D)     (None, 16, 16, 64)   0           ['batch_normalization_87[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 16, 16, 128)  73856       ['block1_pool[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 16, 16, 128)  512        ['block2_conv1[0][0]']
#  ormalization)
#
#  block2_conv2 (Conv2D)          (None, 16, 16, 128)  147584      ['batch_normalization_88[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 16, 16, 128)  512        ['block2_conv2[0][0]']
#  ormalization)
#
#  block2_pool (MaxPooling2D)     (None, 8, 8, 128)    0           ['batch_normalization_89[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 8, 8, 256)    295168      ['block2_pool[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 256)   1024        ['block3_conv1[0][0]']
#  ormalization)
#
#  block3_conv2 (Conv2D)          (None, 8, 8, 256)    590080      ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 256)   1024        ['block3_conv2[0][0]']
#  ormalization)
#
#  block3_conv3 (Conv2D)          (None, 8, 8, 256)    590080      ['batch_normalization_93[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 8, 8, 256)   1024        ['block3_conv3[0][0]']
#  ormalization)
#
#  block3_pool (MaxPooling2D)     (None, 4, 4, 256)    0           ['batch_normalization_94[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 4, 4, 512)    1180160     ['block3_pool[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 4, 4, 512)   2048        ['block4_conv1[0][0]']
#  ormalization)
#
#  block4_conv2 (Conv2D)          (None, 4, 4, 512)    2359808     ['batch_normalization_97[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 4, 4, 512)   2048        ['block4_conv2[0][0]']
#  ormalization)
#
#  block4_conv3 (Conv2D)          (None, 4, 4, 512)    2359808     ['batch_normalization_98[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 4, 4, 512)   2048        ['block4_conv3[0][0]']
#  ormalization)
#
#  block4_pool (MaxPooling2D)     (None, 2, 2, 512)    0           ['batch_normalization_99[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 2, 2, 512)    2359808     ['block4_pool[0][0]']
#
#  batch_normalization_100 (Batch  (None, 2, 2, 512)   2048        ['block5_conv1[0][0]']
#  Normalization)
#
#  block5_conv2 (Conv2D)          (None, 2, 2, 512)    2359808     ['batch_normalization_100[0][0]']
#
#  batch_normalization_101 (Batch  (None, 2, 2, 512)   2048        ['block5_conv2[0][0]']
#  Normalization)
#
#  block5_conv3 (Conv2D)          (None, 2, 2, 512)    2359808     ['batch_normalization_101[0][0]']
#
#  batch_normalization_102 (Batch  (None, 2, 2, 512)   2048        ['block5_conv3[0][0]']
#  Normalization)
#
#  c1_flatten (Flatten)           (None, 8192)         0           ['block2_pool[0][0]']
#
#  c2_flatten (Flatten)           (None, 4096)         0           ['block3_pool[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['batch_normalization_102[0][0]']
#
#  c1_fc_cifar10_1 (Dense)        (None, 256)          2097408     ['c1_flatten[0][0]']
#
#  c2_fc_cifar10_1 (Dense)        (None, 256)          1048832     ['c2_flatten[0][0]']
#
#  fc_cifar10_1 (Dense)           (None, 256)          524544      ['flatten[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 256)         1024        ['c1_fc_cifar10_1[0][0]']
#  ormalization)
#
#  batch_normalization_95 (BatchN  (None, 256)         1024        ['c2_fc_cifar10_1[0][0]']
#  ormalization)
#
#  batch_normalization_103 (Batch  (None, 256)         1024        ['fc_cifar10_1[0][0]']
#  Normalization)
#
#  dropout_28 (Dropout)           (None, 256)          0           ['batch_normalization_90[0][0]']
#
#  dropout_30 (Dropout)           (None, 256)          0           ['batch_normalization_95[0][0]']
#
#  dropout_32 (Dropout)           (None, 256)          0           ['batch_normalization_103[0][0]']
#
#  c1_fc2 (Dense)                 (None, 256)          65792       ['dropout_28[0][0]']
#
#  c2_fc2 (Dense)                 (None, 256)          65792       ['dropout_30[0][0]']
#
#  fc_cifar10_2 (Dense)           (None, 256)          65792       ['dropout_32[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 256)         1024        ['c1_fc2[0][0]']
#  ormalization)
#
#  batch_normalization_96 (BatchN  (None, 256)         1024        ['c2_fc2[0][0]']
#  ormalization)
#
#  batch_normalization_104 (Batch  (None, 256)         1024        ['fc_cifar10_2[0][0]']
#  Normalization)
#
#  dropout_29 (Dropout)           (None, 256)          0           ['batch_normalization_91[0][0]']
#
#  dropout_31 (Dropout)           (None, 256)          0           ['batch_normalization_96[0][0]']
#
#  dropout_33 (Dropout)           (None, 256)          0           ['batch_normalization_104[0][0]']
#
#  fc1_1 (Dense)                  (None, 64)           16448       ['dropout_29[0][0]']
#
#  fc1_3 (Dense)                  (None, 64)           16448       ['dropout_31[0][0]']
#
#  fc1_5 (Dense)                  (None, 64)           16448       ['dropout_33[0][0]']
#
#  fc2_1 (Dense)                  (None, 64)           16448       ['dropout_29[0][0]']
#
#  fc2_3 (Dense)                  (None, 64)           16448       ['dropout_31[0][0]']
#
#  fc2_5 (Dense)                  (None, 64)           16448       ['dropout_33[0][0]']
#
#  fc3_1 (Dense)                  (None, 64)           16448       ['dropout_29[0][0]']
#
#  fc3_3 (Dense)                  (None, 64)           16448       ['dropout_31[0][0]']
#
#  fc3_5 (Dense)                  (None, 64)           16448       ['dropout_33[0][0]']
#
#  fc1_2 (Dense)                  (None, 1)            65          ['fc1_1[0][0]']
#
#  fc1_4 (Dense)                  (None, 1)            65          ['fc1_3[0][0]']
#
#  fc1_6 (Dense)                  (None, 1)            65          ['fc1_5[0][0]']
#
#  fc2_2 (Dense)                  (None, 1)            65          ['fc2_1[0][0]']
#
#  fc2_4 (Dense)                  (None, 1)            65          ['fc2_3[0][0]']
#
#  fc2_6 (Dense)                  (None, 1)            65          ['fc2_5[0][0]']
#
#  fc3_2 (Dense)                  (None, 1)            65          ['fc3_1[0][0]']
#
#  fc3_4 (Dense)                  (None, 1)            65          ['fc3_3[0][0]']
#
#  fc3_6 (Dense)                  (None, 1)            65          ['fc3_5[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 3)            0           ['fc1_2[0][0]',
#                                                                   'fc1_4[0][0]',
#                                                                   'fc1_6[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 3)            0           ['fc2_2[0][0]',
#                                                                   'fc2_4[0][0]',
#                                                                   'fc2_6[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 3)            0           ['fc3_2[0][0]',
#                                                                   'fc3_4[0][0]',
#                                                                   'fc3_6[0][0]']
#
#  attention_weights_1 (Activatio  (None, 3)           0           ['concatenate_8[0][0]']
#  n)
#
#  attention_weights_2 (Activatio  (None, 3)           0           ['concatenate_10[0][0]']
#  n)
#
#  attention_weights_3 (Activatio  (None, 3)           0           ['concatenate_12[0][0]']
#  n)
#
#  tf.__operators__.getitem_18 (S  (3,)                0           ['attention_weights_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_20 (S  (3,)                0           ['attention_weights_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_22 (S  (3,)                0           ['attention_weights_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_24 (S  (3,)                0           ['attention_weights_2[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_26 (S  (3,)                0           ['attention_weights_2[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_28 (S  (3,)                0           ['attention_weights_2[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_30 (S  (3,)                0           ['attention_weights_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_32 (S  (3,)                0           ['attention_weights_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_34 (S  (3,)                0           ['attention_weights_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_19 (S  ()                  0           ['tf.__operators__.getitem_18[0][
#  licingOpLambda)                                                 0]']
#
#  tf.__operators__.getitem_21 (S  ()                  0           ['tf.__operators__.getitem_20[0][
#  licingOpLambda)                                                 0]']
#
#  tf.__operators__.getitem_23 (S  ()                  0           ['tf.__operators__.getitem_22[0][
#  licingOpLambda)                                                 0]']
#
#  tf.__operators__.getitem_25 (S  ()                  0           ['tf.__operators__.getitem_24[0][
#  licingOpLambda)                                                 0]']
#
#  tf.__operators__.getitem_27 (S  ()                  0           ['tf.__operators__.getitem_26[0][
#  licingOpLambda)                                                 0]']
#
#  tf.__operators__.getitem_29 (S  ()                  0           ['tf.__operators__.getitem_28[0][
#  licingOpLambda)                                                 0]']
#
#  tf.__operators__.getitem_31 (S  ()                  0           ['tf.__operators__.getitem_30[0][
#  licingOpLambda)                                                 0]']
#
#  tf.__operators__.getitem_33 (S  ()                  0           ['tf.__operators__.getitem_32[0][
#  licingOpLambda)                                                 0]']
#
#  tf.__operators__.getitem_35 (S  ()                  0           ['tf.__operators__.getitem_34[0][
#  licingOpLambda)                                                 0]']
#
#  tf.math.multiply_9 (TFOpLambda  (None, 256)         0           ['dropout_29[0][0]',
#  )                                                                'tf.__operators__.getitem_19[0][
#                                                                  0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 256)         0           ['dropout_31[0][0]',
#  a)                                                               'tf.__operators__.getitem_21[0][
#                                                                  0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 256)         0           ['dropout_33[0][0]',
#  a)                                                               'tf.__operators__.getitem_23[0][
#                                                                  0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, 256)         0           ['dropout_29[0][0]',
#  a)                                                               'tf.__operators__.getitem_25[0][
#                                                                  0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None, 256)         0           ['dropout_31[0][0]',
#  a)                                                               'tf.__operators__.getitem_27[0][
#                                                                  0]']
#
#  tf.math.multiply_14 (TFOpLambd  (None, 256)         0           ['dropout_33[0][0]',
#  a)                                                               'tf.__operators__.getitem_29[0][
#                                                                  0]']
#
#  tf.math.multiply_15 (TFOpLambd  (None, 256)         0           ['dropout_29[0][0]',
#  a)                                                               'tf.__operators__.getitem_31[0][
#                                                                  0]']
#
#  tf.math.multiply_16 (TFOpLambd  (None, 256)         0           ['dropout_31[0][0]',
#  a)                                                               'tf.__operators__.getitem_33[0][
#                                                                  0]']
#
#  tf.math.multiply_17 (TFOpLambd  (None, 256)         0           ['dropout_33[0][0]',
#  a)                                                               'tf.__operators__.getitem_35[0][
#                                                                  0]']
#
#  add_3 (Add)                    (None, 256)          0           ['tf.math.multiply_9[0][0]',
#                                                                   'tf.math.multiply_10[0][0]',
#                                                                   'tf.math.multiply_11[0][0]']
#
#  add_4 (Add)                    (None, 256)          0           ['tf.math.multiply_12[0][0]',
#                                                                   'tf.math.multiply_13[0][0]',
#                                                                   'tf.math.multiply_14[0][0]']
#
#  add_5 (Add)                    (None, 256)          0           ['tf.math.multiply_15[0][0]',
#                                                                   'tf.math.multiply_16[0][0]',
#                                                                   'tf.math.multiply_17[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 512)          0           ['dropout_29[0][0]',
#                                                                   'add_3[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 512)          0           ['dropout_31[0][0]',
#                                                                   'add_4[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 512)          0           ['dropout_33[0][0]',
#                                                                   'add_5[0][0]']
#
#  c1_predictions_cifar10 (Dense)  (None, 2)           1026        ['concatenate_9[0][0]']
#
#  c2_predictions_cifar10 (Dense)  (None, 7)           3591        ['concatenate_11[0][0]']
#
#  predictions_cifar10 (Dense)    (None, 10)           5130        ['concatenate_13[0][0]']
#
# ==================================================================================================
# Total params: 18,764,252
# Trainable params: 18,752,732
# Non-trainable params: 11,520
# __________________________________________________________________________________________________

# %%
# Callbacks 
change_lr = LearningRateScheduler(scheduler)
change_lw = LossWeightsModifier(alpha, beta, gamma)

if bt_strategy == True:
  cbks = [change_lr, change_lw]
else:
  cbks = [change_lr]

history_bcnn_b = model.fit(x_train, [y_c1_train, y_c2_train, y_train],
          batch_size=batch_size,
          epochs=epochs,
          verbose=0,
          callbacks=cbks,
          validation_data=(x_test, [y_c1_test, y_c2_test, y_test]))

score_ba_cnn_c = model.evaluate(x_test, [y_c1_test, y_c2_test, y_test], verbose=0)
parameters_ba_cnn_c = np.sum([K.count_params(w) for w in model.trainable_weights])

predictions = model.predict(x_test)
preci_ba_cnn_c,reca_ba_cnn_c,f1_ba_cnn_c= hierarchical_metrics([y_c1_test, y_c2_test, y_test],predictions)

# Results
print("--- BA-CNN Base C ---")
print("--- Accuracy per level ---")
print("Accuracy level 1:",score_ba_cnn_c[4])
print("Accuracy level 2:",score_ba_cnn_c[5])
print("Accuracy level 3:",score_ba_cnn_c[6])
print("--- Hierarchical Metrics ---")
print("Precision:",preci_ba_cnn_c)
print("Recall:",reca_ba_cnn_c)
print("f1:",f1_ba_cnn_c)
print("Parameters:","{:,}".format(parameters_ba_cnn_c))
# Out:
# --- BA-CNN Base C ---
# --- Accuracy per level ---
# Accuracy level 1: 0.9833999872207642
# Accuracy level 2: 0.9225999712944031
# Accuracy level 3: 0.888700008392334
# --- Hierarchical Metrics ---
# Precision: 0.9437250258990676
# Recall: 0.9447037037037037
# f1: 0.9442141112015991
# Parameters: 18,752,732

# %% [markdown]
# # H-CNN Base C

# %%
# if True, the model uses BT-strategy for training
bt_strategy = True

# %%
#----------get VGG16 pre-trained weights--------
WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5'
weights_path = get_file('vgg16_weights_tf_dim_ordering_tf_kernels.h5',
                         WEIGHTS_PATH,
                         cache_subdir='models')

#----------------------- model definition ---------------------------
if bt_strategy == True:
  alpha = K.variable(value=0.98, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.01, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.01, dtype="float32", name="gamma") # A3 in paper
else:
  alpha = K.variable(value=0.33, dtype="float32", name="alpha") # A1 in paper
  beta = K.variable(value=0.33, dtype="float32", name="beta") # A2 in paper
  gamma = K.variable(value=0.34, dtype="float32", name="gamma") # A3 in paper  
img_input = Input(shape=input_shape, name='input')

#--- block 1 ---
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

#--- block 2 ---
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

#--- coarse 1 branch ---
c_1_bch_flatt = Flatten(name='c1_flatten')(x)
c_1_bch = Dense(256, activation='relu', name='c1_fc_cifar10_1')(c_1_bch_flatt)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_bch = Dense(256, activation='relu', name='c1_fc2')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_pred = Dense(num_c_1, activation='softmax', name='c1_predictions_cifar10')(c_1_bch)

#--- block 3 ---
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

#--- coarse 2 branch ---
c_2_bch_flatt = Flatten(name='c2_flatten')(x)
c_2_bch_concat = Concatenate()([c_1_bch_flatt,c_2_bch_flatt]) # Conectivity Pattern
c_2_bch = Dense(1024, activation='relu', name='c2_fc_cifar100_1')(c_2_bch_concat)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_bch = Dense(1024, activation='relu', name='c2_fc2')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_pred = Dense(num_c_2, activation='softmax', name='c2_predictions_cifar10')(c_2_bch)

#--- block 4 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

#--- block 5 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
x = BatchNormalization()(x)

#--- fine block ---
x_flatt = Flatten(name='flatten')(x)
x = Concatenate()([c_2_bch_concat,x_flatt]) # Conectivity Pattern
x = Dense(4096, activation='relu', name='fc_cifar10_1')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(4096, activation='relu', name='fc2')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
fine_pred = Dense(num_classes, activation='softmax', name='predictions_cifar10')(x)

model = Model(img_input, [c_1_pred, c_2_pred, fine_pred], name='hcnn_base_c')
model.load_weights(weights_path, by_name=True)
#----------------------- compile and fit ---------------------------
sgd = optimizers.SGD(learning_rate=0.003, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', 
              optimizer=sgd, 
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "hcnn_base_c"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 32, 32, 3)]  0           []
#
#  block1_conv1 (Conv2D)          (None, 32, 32, 64)   1792        ['input[0][0]']
#
#  batch_normalization_105 (Batch  (None, 32, 32, 64)  256         ['block1_conv1[0][0]']
#  Normalization)
#
#  block1_conv2 (Conv2D)          (None, 32, 32, 64)   36928       ['batch_normalization_105[0][0]']
#
#  batch_normalization_106 (Batch  (None, 32, 32, 64)  256         ['block1_conv2[0][0]']
#  Normalization)
#
#  block1_pool (MaxPooling2D)     (None, 16, 16, 64)   0           ['batch_normalization_106[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 16, 16, 128)  73856       ['block1_pool[0][0]']
#
#  batch_normalization_107 (Batch  (None, 16, 16, 128)  512        ['block2_conv1[0][0]']
#  Normalization)
#
#  block2_conv2 (Conv2D)          (None, 16, 16, 128)  147584      ['batch_normalization_107[0][0]']
#
#  batch_normalization_108 (Batch  (None, 16, 16, 128)  512        ['block2_conv2[0][0]']
#  Normalization)
#
#  block2_pool (MaxPooling2D)     (None, 8, 8, 128)    0           ['batch_normalization_108[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 8, 8, 256)    295168      ['block2_pool[0][0]']
#
#  batch_normalization_111 (Batch  (None, 8, 8, 256)   1024        ['block3_conv1[0][0]']
#  Normalization)
#
#  block3_conv2 (Conv2D)          (None, 8, 8, 256)    590080      ['batch_normalization_111[0][0]']
#
#  batch_normalization_112 (Batch  (None, 8, 8, 256)   1024        ['block3_conv2[0][0]']
#  Normalization)
#
#  block3_conv3 (Conv2D)          (None, 8, 8, 256)    590080      ['batch_normalization_112[0][0]']
#
#  batch_normalization_113 (Batch  (None, 8, 8, 256)   1024        ['block3_conv3[0][0]']
#  Normalization)
#
#  block3_pool (MaxPooling2D)     (None, 4, 4, 256)    0           ['batch_normalization_113[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 4, 4, 512)    1180160     ['block3_pool[0][0]']
#
#  batch_normalization_116 (Batch  (None, 4, 4, 512)   2048        ['block4_conv1[0][0]']
#  Normalization)
#
#  block4_conv2 (Conv2D)          (None, 4, 4, 512)    2359808     ['batch_normalization_116[0][0]']
#
#  batch_normalization_117 (Batch  (None, 4, 4, 512)   2048        ['block4_conv2[0][0]']
#  Normalization)
#
#  block4_conv3 (Conv2D)          (None, 4, 4, 512)    2359808     ['batch_normalization_117[0][0]']
#
#  batch_normalization_118 (Batch  (None, 4, 4, 512)   2048        ['block4_conv3[0][0]']
#  Normalization)
#
#  block4_pool (MaxPooling2D)     (None, 2, 2, 512)    0           ['batch_normalization_118[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 2, 2, 512)    2359808     ['block4_pool[0][0]']
#
#  batch_normalization_119 (Batch  (None, 2, 2, 512)   2048        ['block5_conv1[0][0]']
#  Normalization)
#
#  block5_conv2 (Conv2D)          (None, 2, 2, 512)    2359808     ['batch_normalization_119[0][0]']
#
#  batch_normalization_120 (Batch  (None, 2, 2, 512)   2048        ['block5_conv2[0][0]']
#  Normalization)
#
#  block5_conv3 (Conv2D)          (None, 2, 2, 512)    2359808     ['batch_normalization_120[0][0]']
#
#  c1_flatten (Flatten)           (None, 8192)         0           ['block2_pool[0][0]']
#
#  c2_flatten (Flatten)           (None, 4096)         0           ['block3_pool[0][0]']
#
#  batch_normalization_121 (Batch  (None, 2, 2, 512)   2048        ['block5_conv3[0][0]']
#  Normalization)
#
#  concatenate_14 (Concatenate)   (None, 12288)        0           ['c1_flatten[0][0]',
#                                                                   'c2_flatten[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['batch_normalization_121[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 14336)        0           ['concatenate_14[0][0]',
#                                                                   'flatten[0][0]']
#
#  c1_fc_cifar10_1 (Dense)        (None, 256)          2097408     ['c1_flatten[0][0]']
#
#  c2_fc_cifar100_1 (Dense)       (None, 1024)         12583936    ['concatenate_14[0][0]']
#
#  fc_cifar10_1 (Dense)           (None, 4096)         58724352    ['concatenate_15[0][0]']
#
#  batch_normalization_109 (Batch  (None, 256)         1024        ['c1_fc_cifar10_1[0][0]']
#  Normalization)
#
#  batch_normalization_114 (Batch  (None, 1024)        4096        ['c2_fc_cifar100_1[0][0]']
#  Normalization)
#
#  batch_normalization_122 (Batch  (None, 4096)        16384       ['fc_cifar10_1[0][0]']
#  Normalization)
#
#  dropout_34 (Dropout)           (None, 256)          0           ['batch_normalization_109[0][0]']
#
#  dropout_36 (Dropout)           (None, 1024)         0           ['batch_normalization_114[0][0]']
#
#  dropout_38 (Dropout)           (None, 4096)         0           ['batch_normalization_122[0][0]']
#
#  c1_fc2 (Dense)                 (None, 256)          65792       ['dropout_34[0][0]']
#
#  c2_fc2 (Dense)                 (None, 1024)         1049600     ['dropout_36[0][0]']
#
#  fc2 (Dense)                    (None, 4096)         16781312    ['dropout_38[0][0]']
#
#  batch_normalization_110 (Batch  (None, 256)         1024        ['c1_fc2[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 1024)        4096        ['c2_fc2[0][0]']
#  Normalization)
#
#  batch_normalization_123 (Batch  (None, 4096)        16384       ['fc2[0][0]']
#  Normalization)
#
#  dropout_35 (Dropout)           (None, 256)          0           ['batch_normalization_110[0][0]']
#
#  dropout_37 (Dropout)           (None, 1024)         0           ['batch_normalization_115[0][0]']
#
#  dropout_39 (Dropout)           (None, 4096)         0           ['batch_normalization_123[0][0]']
#
#  c1_predictions_cifar10 (Dense)  (None, 2)           514         ['dropout_35[0][0]']
#
#  c2_predictions_cifar10 (Dense)  (None, 7)           7175        ['dropout_37[0][0]']
#
#  predictions_cifar10 (Dense)    (None, 10)           40970       ['dropout_39[0][0]']
#
# ==================================================================================================
# Total params: 106,125,651
# Trainable params: 106,095,699
# Non-trainable params: 29,952
# __________________________________________________________________________________________________

# %%
# Callbacks 
change_lr = LearningRateScheduler(scheduler)
change_lw = LossWeightsModifier(alpha, beta, gamma)

if bt_strategy == True:
  cbks = [change_lr, change_lw]
else:
  cbks = [change_lr]

history_bcnn_b = model.fit(x_train, [y_c1_train, y_c2_train, y_train],
          batch_size=batch_size,
          epochs=epochs,
          verbose=0,
          callbacks=cbks,
          validation_data=(x_test, [y_c1_test, y_c2_test, y_test]))

score_h_cnn_c = model.evaluate(x_test, [y_c1_test, y_c2_test, y_test], verbose=0)
parameters_h_cnn_c = np.sum([K.count_params(w) for w in model.trainable_weights])

predictions = model.predict(x_test)
preci_h_cnn_c,reca_h_cnn_c,f1_h_cnn_c= hierarchical_metrics([y_c1_test, y_c2_test, y_test],predictions)

# Results
print("--- H-CNN Base C ---")
print("--- Accuracy per level ---")
print("Accuracy level 1:",score_h_cnn_c[4])
print("Accuracy level 2:",score_h_cnn_c[5])
print("Accuracy level 3:",score_h_cnn_c[6])
print("--- Hierarchical Metrics ---")
print("Precision:",preci_h_cnn_c)
print("Recall:",reca_h_cnn_c)
print("f1:",f1_h_cnn_c)
print("Parameters:","{:,}".format(parameters_h_cnn_c))
# Out:
# --- H-CNN Base C ---
# --- Accuracy per level ---
# Accuracy level 1: 0.9592000246047974
# Accuracy level 2: 0.9002000093460083
# Accuracy level 3: 0.8792999982833862
# --- Hierarchical Metrics ---
# Precision: 0.9280221811460259
# Recall: 0.9297407407407408
# f1: 0.9288806660499537
# Parameters: 106,095,699

# %% [markdown]
# # Summary

# %%
summary = {'':['Flat CNN Base B','B-CNN Base B','BA-CNN Base B','H-CNN Base B'],'Coarse 1': [0,score_b_cnn_b[4],score_ba_cnn_b[4],score_h_cnn_b[4]],'Coarse 2': [0,score_b_cnn_b[5],score_ba_cnn_b[5],score_h_cnn_b[5]],'Fine': [score_base_b[1],score_b_cnn_b[6],score_ba_cnn_b[6],score_h_cnn_b[6]],'Precision':[0,preci_b_cnn_b,preci_ba_cnn_b,preci_h_cnn_b],'Recall':[0,reca_b_cnn_b,reca_ba_cnn_b,reca_h_cnn_b],'f1':[0,f1_b_cnn_b,f1_ba_cnn_b,f1_h_cnn_b],'Parameters': [parameters_base_b ,parameters_b_cnn_b,parameters_ba_cnn_b,parameters_h_cnn_b]}
summary = pd.DataFrame(summary)
summary['Parameters'] = (summary['Parameters'].astype(float)/1000000).round(2).astype(str) + 'MM'
summary = summary.set_index('')
summary.style.highlight_max()
# Out:
# <style type="text/css">
# #T_fc5e3_row1_col2, #T_fc5e3_row2_col0, #T_fc5e3_row2_col1, #T_fc5e3_row2_col3, #T_fc5e3_row2_col4, #T_fc5e3_row2_col5, #T_fc5e3_row2_col6 {
#   background-color: yellow;
# }
# </style>
# <table id="T_fc5e3_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Coarse 1</th>
#       <th class="col_heading level0 col1" >Coarse 2</th>
#       <th class="col_heading level0 col2" >Fine</th>
#       <th class="col_heading level0 col3" >Precision</th>
#       <th class="col_heading level0 col4" >Recall</th>
#       <th class="col_heading level0 col5" >f1</th>
#       <th class="col_heading level0 col6" >Parameters</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc5e3_level0_row0" class="row_heading level0 row0" >Flat CNN Base B</th>
#       <td id="T_fc5e3_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_fc5e3_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_fc5e3_row0_col2" class="data row0 col2" >0.821100</td>
#       <td id="T_fc5e3_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_fc5e3_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_fc5e3_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_fc5e3_row0_col6" class="data row0 col6" >7.85MM</td>
#     </tr>
#     <tr>
#       <th id="T_fc5e3_level0_row1" class="row_heading level0 row1" >B-CNN Base B</th>
#       <td id="T_fc5e3_row1_col0" class="data row1 col0" >0.958100</td>
#       <td id="T_fc5e3_row1_col1" class="data row1 col1" >0.869200</td>
#       <td id="T_fc5e3_row1_col2" class="data row1 col2" >0.843800</td>
#       <td id="T_fc5e3_row1_col3" class="data row1 col3" >0.908019</td>
#       <td id="T_fc5e3_row1_col4" class="data row1 col4" >0.910037</td>
#       <td id="T_fc5e3_row1_col5" class="data row1 col5" >0.909027</td>
#       <td id="T_fc5e3_row1_col6" class="data row1 col6" >12.38MM</td>
#     </tr>
#     <tr>
#       <th id="T_fc5e3_level0_row2" class="row_heading level0 row2" >BA-CNN Base B</th>
#       <td id="T_fc5e3_row2_col0" class="data row2 col0" >0.967900</td>
#       <td id="T_fc5e3_row2_col1" class="data row2 col1" >0.877800</td>
#       <td id="T_fc5e3_row2_col2" class="data row2 col2" >0.842000</td>
#       <td id="T_fc5e3_row2_col3" class="data row2 col3" >0.914134</td>
#       <td id="T_fc5e3_row2_col4" class="data row2 col4" >0.913593</td>
#       <td id="T_fc5e3_row2_col5" class="data row2 col5" >0.913863</td>
#       <td id="T_fc5e3_row2_col6" class="data row2 col6" >8.72MM</td>
#     </tr>
#     <tr>
#       <th id="T_fc5e3_level0_row3" class="row_heading level0 row3" >H-CNN Base B</th>
#       <td id="T_fc5e3_row3_col0" class="data row3 col0" >0.958600</td>
#       <td id="T_fc5e3_row3_col1" class="data row3 col1" >0.871700</td>
#       <td id="T_fc5e3_row3_col2" class="data row3 col2" >0.836900</td>
#       <td id="T_fc5e3_row3_col3" class="data row3 col3" >0.906302</td>
#       <td id="T_fc5e3_row3_col4" class="data row3 col4" >0.910296</td>
#       <td id="T_fc5e3_row3_col5" class="data row3 col5" >0.908295</td>
#       <td id="T_fc5e3_row3_col6" class="data row3 col6" >29.16MM</td>
#     </tr>
#   </tbody>
# </table>

# %%
summary = {'':['Flat CNN Base C','B-CNN Base C','BA-CNN Base C','H-CNN Base C'],'Coarse 1': [0,score_b_cnn_c[4],score_ba_cnn_c[4],score_h_cnn_c[4]],'Coarse 2': [0,score_b_cnn_c[5],score_ba_cnn_c[5],score_h_cnn_c[5]],'Fine': [score_base_c[1],score_b_cnn_c[6],score_ba_cnn_c[6],score_h_cnn_c[6]],'Precision':[0,preci_b_cnn_c,preci_ba_cnn_c,preci_h_cnn_c],'Recall':[0,reca_b_cnn_c,reca_ba_cnn_c,reca_h_cnn_c],'f1':[0,f1_b_cnn_c,f1_ba_cnn_c,f1_h_cnn_c],'Parameters': [parameters_base_c ,parameters_b_cnn_c,parameters_ba_cnn_c,parameters_h_cnn_c]}
summary = pd.DataFrame(summary)
summary['Parameters'] = (summary['Parameters'].astype(float)/1000000).round(2).astype(str) + 'MM'
summary = summary.set_index('')
summary.style.highlight_max()
# Out:
# <style type="text/css">
# #T_f111e_row1_col6, #T_f111e_row2_col0, #T_f111e_row2_col1, #T_f111e_row2_col2, #T_f111e_row2_col3, #T_f111e_row2_col4, #T_f111e_row2_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f111e_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Coarse 1</th>
#       <th class="col_heading level0 col1" >Coarse 2</th>
#       <th class="col_heading level0 col2" >Fine</th>
#       <th class="col_heading level0 col3" >Precision</th>
#       <th class="col_heading level0 col4" >Recall</th>
#       <th class="col_heading level0 col5" >f1</th>
#       <th class="col_heading level0 col6" >Parameters</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f111e_level0_row0" class="row_heading level0 row0" >Flat CNN Base C</th>
#       <td id="T_f111e_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_f111e_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_f111e_row0_col2" class="data row0 col2" >0.884500</td>
#       <td id="T_f111e_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_f111e_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_f111e_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_f111e_row0_col6" class="data row0 col6" >39.95MM</td>
#     </tr>
#     <tr>
#       <th id="T_f111e_level0_row1" class="row_heading level0 row1" >B-CNN Base C</th>
#       <td id="T_f111e_row1_col0" class="data row1 col0" >0.960300</td>
#       <td id="T_f111e_row1_col1" class="data row1 col1" >0.905300</td>
#       <td id="T_f111e_row1_col2" class="data row1 col2" >0.888500</td>
#       <td id="T_f111e_row1_col3" class="data row1 col3" >0.931548</td>
#       <td id="T_f111e_row1_col4" class="data row1 col4" >0.933963</td>
#       <td id="T_f111e_row1_col5" class="data row1 col5" >0.932754</td>
#       <td id="T_f111e_row1_col6" class="data row1 col6" >49.67MM</td>
#     </tr>
#     <tr>
#       <th id="T_f111e_level0_row2" class="row_heading level0 row2" >BA-CNN Base C</th>
#       <td id="T_f111e_row2_col0" class="data row2 col0" >0.983400</td>
#       <td id="T_f111e_row2_col1" class="data row2 col1" >0.922600</td>
#       <td id="T_f111e_row2_col2" class="data row2 col2" >0.888700</td>
#       <td id="T_f111e_row2_col3" class="data row2 col3" >0.943725</td>
#       <td id="T_f111e_row2_col4" class="data row2 col4" >0.944704</td>
#       <td id="T_f111e_row2_col5" class="data row2 col5" >0.944214</td>
#       <td id="T_f111e_row2_col6" class="data row2 col6" >18.75MM</td>
#     </tr>
#     <tr>
#       <th id="T_f111e_level0_row3" class="row_heading level0 row3" >H-CNN Base C</th>
#       <td id="T_f111e_row3_col0" class="data row3 col0" >0.959200</td>
#       <td id="T_f111e_row3_col1" class="data row3 col1" >0.900200</td>
#       <td id="T_f111e_row3_col2" class="data row3 col2" >0.879300</td>
#       <td id="T_f111e_row3_col3" class="data row3 col3" >0.928022</td>
#       <td id="T_f111e_row3_col4" class="data row3 col4" >0.929741</td>
#       <td id="T_f111e_row3_col5" class="data row3 col5" >0.928881</td>
#       <td id="T_f111e_row3_col6" class="data row3 col6" >106.1MM</td>
#     </tr>
#   </tbody>
# </table>
